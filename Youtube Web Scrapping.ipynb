# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
url = "https://www.youtube.com/@PreppyKitchen/videos"

# %%
driver= webdriver.Chrome()
driver.get(url)

# %%
# //*[@id="dismissible"]
#style-scope ytd-rich-grid-media
#class="style-scope ytd-rich-item-renderer"
#//*[@id="video-title"]
#//*[@id="metadata-line"]/span[1]
#//*[@id="metadata-line"]/span[2]
//*[@id="metadata-line"]/span[1]

# %%
#videos = driver.find_element_by_class_name("style-scope ytd-rich-item-renderer")
url = "https://www.youtube.com/@PreppyKitchen/videos"
driver= webdriver.Chrome()
driver.get(url)
videos = driver.find_elements(By.CLASS_NAME,"style-scope ytd-rich-item-renderer")

video_list = []
for video in videos:
    title = video.find_element(By.XPATH, './/*[@id="video-title"]').text
    views= video.find_element(By.XPATH, './/*[@id="metadata-line"]/span[1]').text
    when = video.find_element(By.XPATH, './/*[@id="metadata-line"]/span[2]').text
    vid_item = {
        "title": title,
        "views": views,
        "posted": when
    }
    video_list.append(vid_item)
df = pd.DataFrame(video_list)
df
# Out:
#                                             title       views        posted
# 0                     Easy Cookie in a Mug Recipe   51K views    3 days ago
# 1          Amazing Blood Orange Cheesecake Recipe   44K views    5 days ago
# 2                     Easy Tortellini Soup Recipe   56K views   10 days ago
# 3            The BEST Kitchen Sink Cookies Recipe   66K views   12 days ago
# 4                    Easy Texas Sheet Cake Recipe  194K views   2 weeks ago
# 5                     Easy Black Bean Soup Recipe   93K views   2 weeks ago
# 6              Easy Peanut Butter Cupcakes Recipe   69K views   3 weeks ago
# 7                     Amazing Bran Muffins Recipe   40K views   3 weeks ago
# 8                Easy Chicken Pot Pie Soup Recipe  133K views   1 month ago
# 9                  Amazing Swiss Roll Cake Recipe  161K views   1 month ago
# 10                  Easy Yorkshire Pudding Recipe  114K views   1 month ago
# 11                  Amazing Olive Oil Cake Recipe  161K views   1 month ago
# 12                   Mexican Hot Chocolate Recipe   91K views   1 month ago
# 13                         How to Make Baked Brie   78K views   1 month ago
# 14                  Amazing Hot Chocolate Cookies  138K views   1 month ago
# 15                            Easy Grinch Cookies  126K views   1 month ago
# 16     Chocolate Peppermint Cake | Christmas Cake  109K views   1 month ago
# 17                 Amazing Rainbow Cookies Recipe   99K views   1 month ago
# 18             Homemade Peppermint Patties Recipe  128K views  2 months ago
# 19                          Easy Gingerbread Cake   92K views  2 months ago
# 20  White Chocolate Chip Cranberry Cookies Recipe   96K views  2 months ago
# 21                    Amazing Caramel Cake Recipe  293K views  2 months ago
# 22                 Amazing Roasted Chicken Recipe  212K views  2 months ago
# 23                         Easy Beer Bread Recipe   52K views  2 months ago
# 24                           How to Cook a Turkey  226K views  2 months ago
# 25        Amazing Peanut Butter Cheesecake Recipe  291K views  2 months ago
# 26            Super-Easy Cornbread Muffins Recipe   87K views  2 months ago
# 27                    Gooey Pecan Pie Bars Recipe  181K views  3 months ago
# 28                 Amazing French Silk Pie Recipe  135K views  3 months ago
# 29                         Easy Spice Cake Recipe   82K views  3 months ago
